# %%
import pandas as pd
import datetime
# from sqlalchemy import

# %%
tor_file = 'toronto.csv'
tor_df = pd.read_csv(tor_file)

# %%
tor_df.head()
# Out:
#            X          Y  Index_ event_unique_id            occurrencedate  \
# 0 -79.343094  43.668449     214  GO-20141948968  2014-04-24T11:29:00.000Z
# 1 -79.507927  43.759285     215  GO-20141950728  2014-04-24T13:00:00.000Z
# 2 -79.501663  43.697552     216  GO-20141956416  2014-04-25T13:20:00.000Z
# 3 -79.571510  43.721703     217  GO-20141956867  2014-04-24T17:00:00.000Z
# 4 -79.503487  43.663891     218  GO-20141957505  2014-04-25T16:00:00.000Z
#
#                reporteddate premisetype  ucr_code  ucr_ext            offence  \
# 0  2014-04-24T12:46:00.000Z  Commercial      1610      200  Robbery - Mugging
# 1  2014-04-24T15:58:00.000Z       House      2120      200                B&E
# 2  2014-04-25T13:52:00.000Z   Apartment      1430      100            Assault
# 3  2014-04-25T10:30:00.000Z     Outside      1430      100            Assault
# 4  2014-04-25T16:15:00.000Z   Apartment      1430      100            Assault
#
# ...

# %%
tor_df1 = tor_df[['Index_', 'premisetype', 'offence', 'occurrenceyear', 'occurrencemonth', 'occurrenceday', 'occurrencedayofweek', 'occurrencehour', 'MCI', 'Neighbourhood']]
tor_df1.rename(columns={'Index_':'id'})
tor_df1.head()
# Out:
#    Index_ premisetype            offence  occurrenceyear occurrencemonth  \
# 0     214  Commercial  Robbery - Mugging          2014.0           April
# 1     215       House                B&E          2014.0           April
# 2     216   Apartment            Assault          2014.0           April
# 3     217     Outside            Assault          2014.0           April
# 4     218   Apartment            Assault          2014.0           April
#
#    occurrenceday occurrencedayofweek  occurrencehour              MCI  \
# 0           24.0          Thursday                11          Robbery
# 1           24.0          Thursday                13  Break and Enter
# 2           25.0          Friday                  13          Assault
# 3           24.0          Thursday                17          Assault
# 4           25.0          Friday                  16          Assault
#
#               Neighbourhood
# 0      North Riverdale (68)
# 1          Black Creek (24)
# ...

# %%
tor_df1['date']=tor_df1.datetime.date(tor_df1['occurenceyear'],tor_df1['occurencemonth'], tor_df1['occurenceday'])
tor_df1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e784ba191a42> in <module>
# ----> 1 tor_df1['date']=tor_df1.datetime.date(tor_df1['occurenceyear'],tor_df1['occurencemonth'], tor_df1['occurenceday'])
#       2 tor_df1.head()
#
# ~\anaconda\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'datetime'
